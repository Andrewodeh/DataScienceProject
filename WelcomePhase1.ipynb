# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrewodeh/DataScienceProject/blob/main/WelcomePhase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Welcome Phase 1");
# Out:
# Welcome Phase 1
